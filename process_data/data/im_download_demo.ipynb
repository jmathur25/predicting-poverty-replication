# %%
access = None
with open('api_key.txt', 'r') as f:
    access = f.readlines()[0]

# %%
lat = 38.441332
lon = -105.234751

# %%
url = "https://maps.googleapis.com/maps/api/staticmap?center={},{}&zoom=14&size=400x400&maptype=satellite&key={}".format(lat, lon, access)

# %%
import requests

# %%
res = requests.get(url)

# %%
from io import BytesIO
from PIL import Image
Image.open(BytesIO(res.content))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=400x400 at 0x10F2BC518>
