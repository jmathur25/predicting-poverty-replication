# %%
api = 'AIzaSyBeJiUKJvtwgFqRJMw2S-cd2k02EkXIwbM'

# %%
url = "https://maps.googleapis.com/maps/api/staticmap?center=-16.941666,35.208332&zoom=16&size=400x400&maptype=satellite&key={}".format(api)

# %%
import requests

# %%
res = requests.get(url)

# %%
from io import BytesIO
from PIL import Image
Image.open(BytesIO(res.content))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=400x400 at 0x7FE2998C82E8>
